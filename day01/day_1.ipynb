# %%
import sys
import os
import csv
import numpy as np

# %%
with open ("input_data", "r", newline = '\n') as inp_data:
    #data = inp_data.read()
    data = csv.reader(inp_data, delimiter = '\n')
    final_data = []
    for elem in data:
        final_data.extend(elem)
final_data = list(map(int, final_data))

# %%
final_data = list(map(int, final_data))

# %%
number_of_accends = 0

# %%
text_file = open("input_data", "r")
lines = text_file.read().split('\n')
#same!

# %%
test_data = [199,
200,
208,
210,
200,
207,
240,
269,
260,
263]

# %%
test_data
# Out:
# [199, 200, 208, 210, 200, 207, 240, 269, 260, 263]

# %%
asc_number = 0
for i in range(len(final_data)-1):
    #print(i)
    if final_data[i] < final_data[i+1]:
        #print('yes')
        asc_number += 1
# if final_data[-2] < final_data[-1]:
#     asc_number +=1

# %%
### part2 sliding window

# %%
final_data = test_data

# %%
asc_number = 0
for i in range(len(final_data) - 3):
    sum_window_1 = final_data[i] + final_data[i+1] + final_data[i+2]
    sum_window_2 = final_data[i+1] + final_data[i+2] + final_data[i+3]
    if sum_window_1 < sum_window_2:
        asc_number += 1

# %%
asc_number
# Out:
# 1618
