# %%
import sys
import os
import csv
import numpy

# %%
with open ("input.txt", "r", newline = '\n') as inp_data:
    data = csv.reader(inp_data, delimiter = '\n')
    input_data = []
    for line in data:
        input_data.extend(line)

# %%
input_data[0]
# Out:
# '194,556 -> 739,556'

# %%
len(input_data)
# Out:
# 500

# %%
input_data[0]
# Out:
# ['194', '556', '739', '556']

# %%
for i in range(len(input_data)):
    input_data[i] = (",".join(input_data[i].split(' -> '))).split(",")

# %%
input_data_clean = []
for i in range(len(input_data)):
    input_data_clean.append(list(map(int, input_data[i])))

# %%
straight_lines = []
for i in (range(len(input_data_clean))):
    if input_data_clean[i][0] == input_data_clean[i][2] or input_data_clean[i][1] == input_data_clean[i][3]:
        print(input_data_clean[i][0])
        straight_lines.append(input_data_clean[i])

# %%
straight_lines
# Out:
# [[194, 556, 739, 556],
#  [818, 920, 818, 524],
#  [277, 205, 85, 205],
#  [782, 901, 782, 186],
#  [969, 96, 969, 648],
#  [504, 971, 989, 971],
#  [926, 151, 926, 480],
#  [722, 895, 722, 488],
#  [732, 418, 157, 418],
#  [116, 652, 893, 652],
#  [827, 196, 827, 564],
#  [677, 515, 677, 257],
#  [380, 897, 132, 897],
#  [812, 959, 812, 23],
#  [989, 382, 294, 382],
#  [441, 394, 441, 469],
#  [502, 662, 502, 213],
#  [609, 570, 609, 58],
#  [559, 47, 208, 47],
#  [77, 192, 277, 192],
#  [229, 588, 66, 588],
#  [705, 363, 705, 161],
#  [699, 889, 699, 354],
#  [360, 272, 966, 272],
#  [264, 631, 630, 631],
#  [541, 50, 541, 911],
#  [163, 625, 163, 513],
#  [642, 971, 642, 754],
#  [975, 329, 793, 329],
#  [793, 878, 793, 938],
#  [10, 95, 175, 95],
#  [352, 903, 352, 176],
#  [649, 768, 649, 136],
#  [347, 492, 347, 977],
#  [372, 839, 372, 741],
#  [587, 534, 526, 534],
#  [126, 708, 362, 708],
#  [326, 869, 326, 640],
#  [358, 959, 358, 408],
#  [221, 99, 221, 659],
#  [17, 896, 642, 896],
#  [488, 135, 851, 135],
#  [54, 76, 184, 76],
#  [290, 596, 290, 478],
#  [468, 427, 468, 316],
#  [412, 434, 412, 581],
#  [647, 231, 542, 231],
#  [586, 555, 13, 555],
#  [708, 862, 100, 862],
#  [259, 533, 259, 516],
#  [745, 929, 745, 569],
#  [111, 100, 499, 100],
#  [638, 903, 525, 903],
#  [726, 388, 973, 388],
#  [335, 504, 638, 504],
#  [628, 29, 159, 29],
#  [375, 406, 200, 406],
#  [12, 819, 945, 819],
#  [436, 477, 436, 988],
#  [925, 41, 464, 41],
#  [868, 485, 868, 109],
#  [895, 50, 895, 568],
#  [582, 943, 582, 904],
#  [589, 616, 589, 590],
#  [396, 22, 396, 730],
#  [726, 743, 726, 934],
#  [360, 170, 360, 187],
#  [597, 287, 982, 287],
#  [537, 112, 838, 112],
#  [702, 683, 151, 683],
#  [770, 792, 752, 792],
#  [964, 60, 896, 60],
#  [53, 642, 278, 642],
#  [96, 950, 96, 983],
#  [251, 65, 289, 65],
#  [797, 666, 797, 200],
#  [582, 157, 582, 538],
#  [124, 911, 347, 911],
#  [974, 538, 974, 318],
#  [163, 939, 709, 939],
#  [351, 540, 351, 954],
#  [278, 314, 278, 146],
#  [637, 784, 637, 283],
#  [83, 690, 899, 690],
#  [333, 631, 333, 832],
#  [527, 652, 527, 836],
#  [352, 343, 352, 623],
#  [450, 86, 489, 86],
#  [814, 834, 814, 494],
#  [406, 947, 783, 947],
#  [811, 643, 318, 643],
#  [240, 651, 366, 651],
#  [843, 939, 729, 939],
#  [365, 459, 222, 459],
#  [746, 415, 746, 199],
#  [760, 923, 860, 923],
#  [506, 259, 506, 357],
#  [933, 892, 143, 892],
#  [88, 589, 88, 77],
#  [597, 554, 810, 554],
#  [505, 574, 505, 812],
#  [387, 238, 480, 238],
#  [526, 436, 526, 12],
#  [660, 397, 660, 290],
#  [856, 469, 176, 469],
#  [653, 731, 370, 731],
#  [542, 241, 542, 32],
#  [471, 734, 471, 384],
#  [975, 468, 783, 468],
#  [25, 578, 580, 578],
#  [150, 791, 672, 791],
#  [643, 348, 643, 869],
#  [893, 514, 893, 422],
#  [400, 463, 335, 463],
#  [564, 917, 676, 917],
#  [166, 433, 166, 246],
#  [118, 977, 882, 977],
#  [718, 415, 75, 415],
#  [690, 807, 690, 659],
#  [163, 809, 269, 809],
#  [715, 238, 715, 314],
#  [683, 762, 683, 467],
#  [361, 130, 361, 66],
#  [879, 491, 879, 843],
#  [515, 700, 515, 454],
#  [465, 432, 465, 444],
#  [894, 818, 163, 818],
#  [190, 790, 190, 616],
#  [384, 263, 384, 84],
#  [21, 592, 883, 592],
#  [972, 447, 972, 639],
#  [838, 60, 681, 60],
#  [38, 366, 38, 907],
#  [746, 65, 459, 65],
#  [138, 640, 66, 640],
#  [536, 309, 536, 109],
#  [772, 634, 772, 566],
#  [914, 85, 395, 85],
#  [679, 455, 679, 439],
#  [420, 492, 614, 492],
#  [823, 658, 823, 634],
#  [45, 332, 45, 943],
#  [807, 344, 807, 756],
#  [634, 974, 634, 892],
#  [628, 772, 15, 772],
#  [829, 614, 550, 614],
#  [513, 649, 513, 369],
#  [607, 923, 607, 801],
#  [550, 193, 666, 193],
#  [467, 146, 500, 146],
#  [543, 510, 543, 626],
#  [667, 52, 667, 161],
#  [635, 299, 375, 299],
#  [278, 807, 904, 807],
#  [269, 290, 644, 290],
#  [630, 268, 630, 440],
#  [864, 907, 360, 907],
#  [455, 894, 455, 265],
#  [257, 43, 257, 519],
#  [414, 83, 360, 83],
#  [237, 64, 237, 612],
#  [260, 541, 260, 927],
#  [323, 909, 323, 583],
#  [929, 354, 929, 695],
#  [579, 401, 392, 401],
#  [831, 696, 831, 707],
#  [871, 304, 212, 304],
#  [207, 333, 621, 333],
#  [115, 397, 115, 208],
#  [889, 217, 985, 217],
#  [793, 402, 250, 402],
#  [39, 564, 39, 481],
#  [283, 816, 346, 816],
#  [383, 506, 276, 506],
#  [394, 661, 394, 143],
#  [652, 638, 652, 569],
#  [185, 64, 487, 64],
#  [354, 935, 251, 935],
#  [201, 460, 201, 552],
#  [836, 285, 836, 666],
#  [243, 959, 22, 959],
#  [573, 323, 834, 323],
#  [745, 734, 456, 734],
#  [594, 244, 908, 244],
#  [288, 38, 288, 364],
#  [215, 196, 215, 476],
#  [270, 705, 586, 705],
#  [749, 477, 749, 658],
#  [935, 187, 935, 381],
#  [399, 491, 399, 779],
#  [160, 115, 58, 115],
#  [940, 68, 940, 590],
#  [283, 904, 283, 114],
#  [344, 935, 222, 935],
#  [435, 962, 367, 962],
#  [837, 768, 837, 583],
#  [100, 423, 826, 423],
#  [299, 172, 465, 172],
#  [969, 759, 55, 759],
#  [936, 711, 521, 711],
#  [268, 619, 349, 619],
#  [535, 202, 321, 202],
#  [887, 208, 887, 265],
#  [129, 12, 42, 12],
#  [722, 306, 722, 418],
#  [798, 279, 798, 293],
#  [384, 701, 193, 701],
#  [100, 644, 593, 644],
#  [818, 48, 216, 48],
#  [843, 494, 843, 723],
#  [500, 38, 656, 38],
#  [311, 705, 311, 101],
#  [21, 850, 21, 316],
#  [530, 628, 511, 628],
#  [987, 937, 987, 793],
#  [768, 149, 914, 149],
#  [548, 71, 548, 812],
#  [51, 946, 812, 946],
#  [529, 301, 133, 301],
#  [282, 890, 720, 890],
#  [489, 471, 934, 471],
#  [585, 174, 100, 174],
#  [284, 489, 163, 489],
#  [31, 213, 662, 213],
#  [730, 345, 730, 194],
#  [110, 351, 581, 351],
#  [674, 671, 674, 711],
#  [514, 867, 514, 100],
#  [885, 595, 885, 680],
#  [969, 347, 69, 347],
#  [597, 227, 357, 227],
#  [347, 443, 347, 216],
#  [781, 736, 781, 93],
#  [968, 559, 968, 81],
#  [35, 93, 232, 93],
#  [273, 837, 97, 837],
#  [712, 773, 221, 773],
#  [217, 816, 217, 861],
#  [651, 122, 71, 122],
#  [166, 551, 166, 892],
#  [285, 193, 883, 193],
#  [180, 190, 577, 190],
#  [455, 571, 753, 571],
#  [11, 769, 11, 507],
#  [70, 740, 70, 928],
#  [890, 851, 151, 851],
#  [201, 870, 201, 506],
#  [549, 549, 549, 528],
#  [343, 172, 601, 172],
#  [22, 732, 750, 732],
#  [628, 559, 747, 559],
#  [668, 879, 437, 879],
#  [712, 139, 38, 139],
#  [547, 322, 905, 322],
#  [872, 304, 719, 304],
#  [256, 91, 746, 91],
#  [881, 548, 641, 548],
#  [683, 417, 683, 800],
#  [811, 917, 646, 917],
#  [732, 343, 260, 343],
#  [649, 621, 649, 165],
#  [298, 339, 298, 523],
#  [934, 791, 934, 29],
#  [782, 13, 782, 741],
#  [852, 808, 852, 594],
#  [390, 217, 153, 217],
#  [47, 911, 164, 911],
#  [670, 414, 533, 414],
#  [264, 686, 264, 799],
#  [506, 300, 64, 300],
#  [509, 717, 509, 952],
#  [81, 819, 81, 694],
#  [512, 543, 427, 543],
#  [235, 78, 788, 78],
#  [952, 133, 644, 133],
#  [188, 302, 695, 302],
#  [288, 413, 704, 413],
#  [774, 671, 774, 24],
#  [296, 932, 296, 16],
#  [99, 789, 300, 789],
#  [630, 560, 630, 896],
#  [328, 289, 280, 289],
#  [437, 747, 437, 110],
#  [537, 709, 42, 709],
#  [655, 924, 655, 117],
#  [70, 87, 274, 87],
#  [147, 278, 482, 278],
#  [188, 793, 761, 793],
#  [702, 441, 702, 27],
#  [686, 18, 686, 275],
#  [510, 254, 510, 862],
#  [666, 204, 12, 204],
#  [677, 63, 677, 78],
#  [868, 950, 868, 110],
#  [343, 279, 758, 279],
#  [182, 792, 727, 792],
#  [346, 238, 493, 238],
#  [467, 493, 467, 273],
#  [823, 68, 823, 886],
#  [686, 302, 39, 302],
#  [984, 345, 984, 936],
#  [11, 480, 11, 675],
#  [568, 235, 535, 235],
#  [203, 41, 93, 41],
#  [463, 569, 304, 569],
#  [909, 629, 207, 629],
#  [792, 678, 792, 909],
#  [486, 924, 486, 948],
#  [611, 79, 611, 303],
#  [808, 872, 726, 872],
#  [22, 403, 22, 401],
#  [774, 134, 369, 134],
#  [131, 282, 131, 849],
#  [912, 245, 912, 385],
#  [338, 396, 768, 396],
#  [623, 897, 623, 10],
#  [39, 50, 971, 50],
#  [770, 423, 882, 423],
#  [195, 873, 195, 40],
#  [119, 659, 119, 374],
#  [678, 962, 698, 962],
#  [946, 64, 946, 202],
#  [790, 780, 790, 66],
#  [565, 21, 614, 21],
#  [617, 20, 640, 20],
#  [697, 773, 697, 915],
#  [467, 167, 208, 167],
#  [567, 713, 567, 873],
#  [120, 98, 557, 98],
#  [103, 395, 103, 159],
#  [730, 949, 730, 33],
#  [322, 628, 322, 272],
#  [649, 57, 44, 57],
#  [261, 513, 624, 513],
#  [146, 659, 146, 581],
#  [599, 751, 599, 320],
#  [871, 691, 502, 691],
#  [195, 963, 335, 963],
#  [620, 801, 673, 801],
#  [187, 428, 318, 428],
#  [572, 836, 441, 836],
#  [305, 398, 305, 951],
#  [978, 703, 927, 703],
#  [859, 775, 859, 663],
#  [144, 777, 144, 390],
#  [792, 859, 441, 859],
#  [802, 498, 811, 498],
#  [197, 240, 197, 216],
#  [860, 573, 12, 573],
#  [918, 952, 918, 111],
#  [936, 174, 936, 97],
#  [630, 759, 630, 89],
#  [329, 762, 608, 762]]

# %%
len(straight_lines)
# Out:
# 353

# %%
straight_lines_ranges = []
for i in range(len(straight_lines)):
    straight_lines_ranges.append([range(straight_lines[i][0],straight_lines[i][2]+1), range(straight_lines[i][1],straight_lines[i][3]+1)])

# %%
straight_lines_ranges[0:5]
# Out:
# [[range(194, 740), range(556, 557)],
#  [range(818, 819), range(920, 525)],
#  [range(277, 86), range(205, 206)],
#  [range(782, 783), range(901, 187)],
#  [range(969, 970), range(96, 649)]]

# %%
556 in straight_lines_ranges[0][0]
# Out:
# True

# %%
min(straight_lines_ranges)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-d168b6be1e9a> in <module>
# ----> 1 min(straight_lines_ranges)
#
# TypeError: '<' not supported between instances of 'range' and 'range'

# %%
len(straight_lines_ranges)
# Out:
# 353

# %%
for (i) in range(len(straight_lines_ranges)):
    _ = i

# %%
i
# Out:
# 352
